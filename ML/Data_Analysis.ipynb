# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt

# %%
Data = pd.read_csv(r'C:\Users\falke\VSCODE\ML\Salary_Data.csv')

# %%
Data.head()
# Out:
#    YearsExperience  Salary
# 0              1.1   39343
# 1              1.3   46205
# 2              1.5   37731
# 3              2.0   43525
# 4              2.2   39891

# %%
x = Data.iloc[:, :-1]
y = Data.iloc[:, :-1]

# %%
Data.isnull().sum()
# Out:
# YearsExperience    0
# Salary             0
# dtype: int64

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.3, random_state=0)
# Out:
# Traceback (most recent call last):
#
#   File ~\AppData\Roaming\Python\Python313\site-packages\IPython\core\interactiveshell.py:3699 in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   Cell In[3], line 1
#     from sklearn.model_selection import train_test_split
#
#   File c:\Users\falke\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\__init__.py:84
#     from .base import clone
#
#   File c:\Users\falke\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\base.py:493
#     a            warnings.warn(
#                                ^
# IndentationError: expected an indented block after 'if' statement on line 492

# %%
import sklearn.model_selection
# Out:
# Traceback (most recent call last):
#
#   File ~\AppData\Roaming\Python\Python313\site-packages\IPython\core\interactiveshell.py:3699 in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   Cell In[9], line 1
#     import sklearn.model_selection
#
#   File c:\Users\falke\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\__init__.py:84
#     from .base import clone
#
#   File c:\Users\falke\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\base.py:493
#     a            warnings.warn(
#                                ^
# IndentationError: expected an indented block after 'if' statement on line 492

# %%
# !pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in C:\Users\falke\AppData\Local\Programs\Python\Python313\Lib\site-packages (1.5.2)
# Requirement already satisfied: numpy>=1.19.5 in C:\Users\falke\AppData\Local\Programs\Python\Python313\Lib\site-packages (from scikit-learn) (2.1.3)
# Requirement already satisfied: scipy>=1.6.0 in C:\Users\falke\AppData\Local\Programs\Python\Python313\Lib\site-packages (from scikit-learn) (1.14.1)
# Requirement already satisfied: joblib>=1.2.0 in C:\Users\falke\AppData\Local\Programs\Python\Python313\Lib\site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in C:\Users\falke\AppData\Local\Programs\Python\Python313\Lib\site-packages (from scikit-learn) (3.5.0)

# %%
from sklearn.model_selection import train_test_split
# Out:
# Traceback (most recent call last):
#
#   File ~\AppData\Roaming\Python\Python313\site-packages\IPython\core\interactiveshell.py:3699 in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   Cell In[2], line 1
#     from sklearn.model_selection import train_test_split
#
#   File c:\Users\falke\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\__init__.py:84
#     from .base import clone
#
#   File c:\Users\falke\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\base.py:493
#     a            warnings.warn(
#                                ^
# IndentationError: expected an indented block after 'if' statement on line 492

# %%
from sklearn.linear_model import LinearRegression
regressoor
